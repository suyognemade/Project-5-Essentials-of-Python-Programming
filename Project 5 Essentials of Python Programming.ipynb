# %% [markdown]
# # Project 5: Essentials of Python Programming

# %% [markdown]
# # Virtual Internship Program @ AINE.AI

# %% [markdown]
# # Submitted by Suyog Santosh Nemade
#
# Project: Developing ‘Rock, Paper and Scissors’ game using Python programming.
#
# Aim: Write a Python program to develop a Rock, Papers and Scissors game to be played against a computer.
#
# Objectives: 1.Understand the environment of the Jupyter Notebook on Anaconda 3. 2.Using different cells and comments in the notebook to mention explanations of your program and syntaxes. 3.Understanding basic data types and lists in Python. 4.Working with lists and accessing its elements. 5.Taking user inputs and printing them. 6.Working on the random library 7.Initializing the value of a variable 8.Creating loops asking the play the game multiple times unless the user enters Q 9.Using conditional operators to play the game with different options in different games.

# %%
#import the random module to simulate the computer’s choices
import random

#Declaring the moves
c_moves = ["rock", "paper", "scissors"]

#Selecting a random move for the computer from the given moves
computer = c_moves[random.randint(0, 2)]

player = False
str1="Invalid Input\n"
str2="Please enter 'Rock' 'Paper' or 'Scissors'\n"

print("Welcome to the 'Rock Paper and Scissors' game. Enter any move to start the game.")
print("Enter 'Q' to exit the game.")
print("")

#Implementing the while loop to play indefinitely
while player == False:
    #Taking input from the user
    player = input("Enter your move: ")
    player = player.lower()

    if player == 'q':
        print("Game Exited.")
        break

#Determining a winner
    if computer == player:
        print("Its a Tie!\n")

    #action for user input as Rock
    elif player == 'rock':
        if computer == 'paper':
            print("You lose, Paper covers Rock \n")
        elif computer == 'Scissors':
            print("You win, Rock smashes Scissors\n")

    #action for user input as Paper
    elif player == 'paper':
        if computer == 'scissors':
            print("You lose, Scissors cuts Paper\n")
        elif computer == 'rock':
            print("You win, Paper covers Rock\n")

    #action for user input as Scissors
    elif player == 'scissors':
        if computer == 'rock':
            print("You lose, Rock smashes Scissors\n")
        elif computer == 'paper':
            print("You win, Scissors cuts Paper\n")

    #when user enters an empty input
    elif player == '':
        print("Empty input. Please Enter any of the given moves\n")
    
    #when user enters anything other than the predefined moves
    else:
        print(str1+str2)
        
    player = False
# Out:
# Welcome to the 'Rock Paper and Scissors' game. Enter any move to start the game.
# Enter 'Q' to exit the game.
#
# Enter your move: Paper
# You win, Paper covers Rock
#
# Enter your move: rock
# Its a Tie!
#
# Enter your move: scissors
# You lose, Rock smashes Scissors
